# %%
import pandas as pd

# %%
path1="date=2019-10-02-full.csv"
path2="date=2019-10-03-full.csv"
path3="date=2019-10-04-full.csv"
path4="date=2019-10-05-full.csv"
path5="date=2019-10-06-full.csv"
path6="date=2019-10-07-full.csv"
path7="date=2019-10-08-full.csv"

path8="date=2019-11-01-full.csv"
path9="date=2019-11-02-full.csv"
path10="date=2019-11-03-full.csv"
path11="date=2019-11-04-full.csv"
path12="date=2019-11-05-full.csv"
path13="date=2019-11-06-full.csv"
path14="date=2019-11-07-full.csv"

path15="date=2019-12-06-full.csv"
path16="date=2019-12-07-full.csv"
path17="date=2019-12-08-full.csv"
path18="date=2019-12-09-full.csv"
path19="date=2019-12-10-full.csv"
path20="date=2019-12-11-full.csv"
path21="date=2019-12-12-full.csv"

#path100="cleanfinal_gps.csv"
#df_final_clean=pd.read_csv(path100)

# %%
df1=pd.read_csv(path1)
df2=pd.read_csv(path2)
df3=pd.read_csv(path3)
df4=pd.read_csv(path4)
df5=pd.read_csv(path5)
df6=pd.read_csv(path6)
df7=pd.read_csv(path7)

df8=pd.read_csv(path8)
df9=pd.read_csv(path9)
df10=pd.read_csv(path10)
df11=pd.read_csv(path11)
df12=pd.read_csv(path12)
df13=pd.read_csv(path13)
df14=pd.read_csv(path14)

df15=pd.read_csv(path15)
df16=pd.read_csv(path16)
df17=pd.read_csv(path17)
df18=pd.read_csv(path18)
df19=pd.read_csv(path19)
df20=pd.read_csv(path20)
df21=pd.read_csv(path21)

# %%
day1=df1.driver_id.unique()
day2=df2.driver_id.unique()
day3=df3.driver_id.unique()
day4=df4.driver_id.unique()
day5=df5.driver_id.unique()
day6=df6.driver_id.unique()
day7=df7.driver_id.unique()
day8=df8.driver_id.unique()
day9=df9.driver_id.unique()
day10=df10.driver_id.unique()
day11=df11.driver_id.unique()
day12=df12.driver_id.unique()
day13=df13.driver_id.unique()
day14=df14.driver_id.unique()
day15=df15.driver_id.unique()
day16=df16.driver_id.unique()
day17=df17.driver_id.unique()
day18=df18.driver_id.unique()
day19=df19.driver_id.unique()
day20=df20.driver_id.unique()
day21=df21.driver_id.unique()

# %%
df1
# Out:
#                                                driver_id     tripid  points  \
# 0      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181813898      62
# 1      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181816907     453
# 2      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181844705      91
# 3      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181861325      76
# 4      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181871430      54
# ...                                                  ...        ...     ...
# 27079  ffefa9fc58deb38517fe5176a458e9cac5c125f15bae31...  181840742     257
# 27080  ffefa9fc58deb38517fe5176a458e9cac5c125f15bae31...  181894484     132
# 27081  fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c63...  181848942     118
# 27082  fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c63...  181854776     183
# 27083  fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c63...  181862877     121
#
#        Actualduration   AverageP  distance  duration
# ...

# %%
df=pd.concat([df1, df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21])

# %%
df
# Out:
#                                                driver_id     tripid  points  \
# 0      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181813898      62
# 1      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181816907     453
# 2      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181844705      91
# 3      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181861325      76
# 4      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181871430      54
# ...                                                  ...        ...     ...
# 31461  ffefa9fc58deb38517fe5176a458e9cac5c125f15bae31...  198740997     169
# 31462  fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c63...  198710096     105
# 31463  fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c63...  198740263      20
# 31464  fff81139a7dd8a3a48f462347a5611b8e0b84258237d5d...  198740094     206
# 31465  fffdbe5b5cc6c01d65c9c9a94ad9cd1dc8546b0b107c11...  198820049      10
#
# ...

# %%
del df["Unnamed: 0"]

# %%
df
# Out:
#                                                driver_id     tripid  points  \
# 0      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181813898      62
# 1      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181816907     453
# 2      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181844705      91
# 3      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181861325      76
# 4      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181871430      54
# ...                                                  ...        ...     ...
# 31461  ffefa9fc58deb38517fe5176a458e9cac5c125f15bae31...  198740997     169
# 31462  fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c63...  198710096     105
# 31463  fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c63...  198740263      20
# 31464  fff81139a7dd8a3a48f462347a5611b8e0b84258237d5d...  198740094     206
# 31465  fffdbe5b5cc6c01d65c9c9a94ad9cd1dc8546b0b107c11...  198820049      10
#
#        Actualduration    AverageP  distance  duration
# ...

# %%
df_filtered = df[df["distance"] > 0]
df_filtered = df[df["duration"] > 0]

# %%
df_filtered
# Out:
#                                                driver_id     tripid  points  \
# 0      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181813898      62
# 1      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181816907     453
# 2      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181844705      91
# 3      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181861325      76
# 4      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181871430      54
# ...                                                  ...        ...     ...
# 31461  ffefa9fc58deb38517fe5176a458e9cac5c125f15bae31...  198740997     169
# 31462  fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c63...  198710096     105
# 31463  fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c63...  198740263      20
# 31464  fff81139a7dd8a3a48f462347a5611b8e0b84258237d5d...  198740094     206
# 31465  fffdbe5b5cc6c01d65c9c9a94ad9cd1dc8546b0b107c11...  198820049      10
#
#        Actualduration    AverageP  distance  duration
# ...

# %%
df_driver_summary=df_filtered.groupby('driver_id').agg({'tripid':'count', 'Actualduration': 'sum','distance':'sum'}).reset_index()

# %%
df_driver_summary
# Out:
#                                                driver_id  tripid  \
# 0      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...     113
# 1      000846f85c9630becba208506e1585d2b09340e3386088...       7
# 2      0008e5c2621c9af8918f607347e252e854e1a1c0a3988c...       5
# 3      0009d671d687b1e712a501a25b1887bb93d091144d294a...      19
# 4      00101a8c304d1fef6d74f2757b7a1e6107222806af1a9d...       2
# ...                                                  ...     ...
# 20439  fff2120ba40bd52ada46c020e0a3bff30aba3035beedcc...      23
# 20440  fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c63...      14
# 20441  fff81139a7dd8a3a48f462347a5611b8e0b84258237d5d...      30
# 20442  fff82f20ea5aeea53108ebc30fa6e357b15de100fba744...       4
# 20443  fffdbe5b5cc6c01d65c9c9a94ad9cd1dc8546b0b107c11...       1
#
#        Actualduration  distance
# 0             89414.0    382.04
# 1             22915.0     61.61
# 2              3195.0      8.60
# 3             82872.0    229.46
# ...

# %%
df_driver_summary.columns
# Out:
# Index(['driver_id', 'tripid', 'Actualduration', 'distance'], dtype='object')

# %%
df_driver_summary.rename(columns={'tripid': 'trip_count', 'Actualduration': 'total_trip_duration', 'distance': 'total_trip_distance'})
# Out:
#                                                driver_id  trip_count  \
# 0      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...         113
# 1      000846f85c9630becba208506e1585d2b09340e3386088...           7
# 2      0008e5c2621c9af8918f607347e252e854e1a1c0a3988c...           5
# 3      0009d671d687b1e712a501a25b1887bb93d091144d294a...          19
# 4      00101a8c304d1fef6d74f2757b7a1e6107222806af1a9d...           2
# ...                                                  ...         ...
# 20439  fff2120ba40bd52ada46c020e0a3bff30aba3035beedcc...          23
# 20440  fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c63...          14
# 20441  fff81139a7dd8a3a48f462347a5611b8e0b84258237d5d...          30
# 20442  fff82f20ea5aeea53108ebc30fa6e357b15de100fba744...           4
# 20443  fffdbe5b5cc6c01d65c9c9a94ad9cd1dc8546b0b107c11...           1
#
#        total_trip_duration  total_trip_distance
# 0                  89414.0               382.04
# ...

# %%
df_driver_summary["driver_id"].nunique()
# Out:
# 20444

# %%
df_driver_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20444 entries, 0 to 20443
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   driver_id            20444 non-null  object
#  1   trip_count           20444 non-null  int64
#  2   total_trip_duration  20444 non-null  float64
#  3   total_trip_distance  20444 non-null  float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 639.0+ KB

# %%
df_driver_summary.describe()
# Out:
#          trip_count  total_trip_duration  total_trip_distance
# count  20444.000000         2.044400e+04         20444.000000
# mean      26.832029         5.446601e+04           144.737759
# std       32.230158         7.419114e+04           291.665131
# min        1.000000         2.400000e+01             0.000000
# 25%        5.000000         1.104600e+04            23.400000
# 50%       15.000000         3.236450e+04            78.320000
# 75%       36.000000         7.466025e+04           194.255000
# max      286.000000         3.536777e+06         27512.340000

# %%
df_driver_summary
# Out:
#                                                driver_id  trip_count  \
# 0      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...         113
# 1      000846f85c9630becba208506e1585d2b09340e3386088...           7
# 2      0008e5c2621c9af8918f607347e252e854e1a1c0a3988c...           5
# 3      0009d671d687b1e712a501a25b1887bb93d091144d294a...          19
# 4      00101a8c304d1fef6d74f2757b7a1e6107222806af1a9d...           2
# ...                                                  ...         ...
# 20439  fff2120ba40bd52ada46c020e0a3bff30aba3035beedcc...          23
# 20440  fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c63...          14
# 20441  fff81139a7dd8a3a48f462347a5611b8e0b84258237d5d...          30
# 20442  fff82f20ea5aeea53108ebc30fa6e357b15de100fba744...           4
# 20443  fffdbe5b5cc6c01d65c9c9a94ad9cd1dc8546b0b107c11...           1
#
#        total_trip_duration  total_trip_distance
# 0                  89414.0               382.04
# ...

# %%
a=set(day1).intersection(set(day2)).intersection(set(day3)).intersection(set(day4)).intersection(set(day5)).intersection(set(day6)).intersection(set(day7)).intersection(set(day8)).intersection(set(day9)).intersection(set(day10)).intersection(set(day11)).intersection(set(day12)).intersection(set(day13)).intersection(set(day14)).intersection(set(day15)).intersection(set(day16)).intersection(set(day17)).intersection(set(day18)).intersection(set(day19)).intersection(set(day20)).intersection(set(day21))

# %%
len(a)
# Out:
# 37

# %%
df
# Out:
#                                                driver_id     tripid  points  \
# 0      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181813898      62
# 1      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181816907     453
# 2      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181844705      91
# 3      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181861325      76
# 4      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...  181871430      54
# ...                                                  ...        ...     ...
# 31461  ffefa9fc58deb38517fe5176a458e9cac5c125f15bae31...  198740997     169
# 31462  fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c63...  198710096     105
# 31463  fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c63...  198740263      20
# 31464  fff81139a7dd8a3a48f462347a5611b8e0b84258237d5d...  198740094     206
# 31465  fffdbe5b5cc6c01d65c9c9a94ad9cd1dc8546b0b107c11...  198820049      10
#
#        Actualduration    AverageP  distance  duration
# ...

# %%
df_driver_summary.trip_count.describe()
# Out:
# count    20444.000000
# mean        26.832029
# std         32.230158
# min          1.000000
# 25%          5.000000
# 50%         15.000000
# 75%         36.000000
# max        286.000000
# Name: trip_count, dtype: float64

# %%
df_driver_summary
# Out:
#                                                driver_id  trip_count  \
# 0      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...         113
# 1      000846f85c9630becba208506e1585d2b09340e3386088...           7
# 2      0008e5c2621c9af8918f607347e252e854e1a1c0a3988c...           5
# 3      0009d671d687b1e712a501a25b1887bb93d091144d294a...          19
# 4      00101a8c304d1fef6d74f2757b7a1e6107222806af1a9d...           2
# ...                                                  ...         ...
# 20439  fff2120ba40bd52ada46c020e0a3bff30aba3035beedcc...          23
# 20440  fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c63...          14
# 20441  fff81139a7dd8a3a48f462347a5611b8e0b84258237d5d...          30
# 20442  fff82f20ea5aeea53108ebc30fa6e357b15de100fba744...           4
# 20443  fffdbe5b5cc6c01d65c9c9a94ad9cd1dc8546b0b107c11...           1
#
#        total_trip_duration  total_trip_distance
# 0                  89414.0               382.04
# ...

# %%
df_driver_summary["driver_id"].nunique()
# Out:
# 20444

# %%
df_driver_summary['trip_count'].sum()
# Out:
# 548554

# %%
548554/20444
# Out:
# 26.83202895715124

# %%
df_driver_summary['trip_count'].describe()
# Out:
# count    20444.000000
# mean        26.832029
# std         32.230158
# min          1.000000
# 25%          5.000000
# 50%         15.000000
# 75%         36.000000
# max        286.000000
# Name: trip_count, dtype: float64

# %%
df_driver_summary
# Out:
#                                                driver_id  trip_count  \
# 0      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...         113
# 1      000846f85c9630becba208506e1585d2b09340e3386088...           7
# 2      0008e5c2621c9af8918f607347e252e854e1a1c0a3988c...           5
# 3      0009d671d687b1e712a501a25b1887bb93d091144d294a...          19
# 4      00101a8c304d1fef6d74f2757b7a1e6107222806af1a9d...           2
# ...                                                  ...         ...
# 20439  fff2120ba40bd52ada46c020e0a3bff30aba3035beedcc...          23
# 20440  fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c63...          14
# 20441  fff81139a7dd8a3a48f462347a5611b8e0b84258237d5d...          30
# 20442  fff82f20ea5aeea53108ebc30fa6e357b15de100fba744...           4
# 20443  fffdbe5b5cc6c01d65c9c9a94ad9cd1dc8546b0b107c11...           1
#
#        total_trip_duration  total_trip_distance
# 0                  89414.0               382.04
# ...

# %%
df_driver_summary.describe()
# Out:
#          trip_count  total_trip_duration  total_trip_distance
# count  20444.000000         2.044400e+04         20444.000000
# mean      26.832029         5.446601e+04           144.737759
# std       32.230158         7.419114e+04           291.665131
# min        1.000000         2.400000e+01             0.000000
# 25%        5.000000         1.104600e+04            23.400000
# 50%       15.000000         3.236450e+04            78.320000
# 75%       36.000000         7.466025e+04           194.255000
# max      286.000000         3.536777e+06         27512.340000

# %%
df_driver_summary
# Out:
#                                                driver_id  trip_count  \
# 0      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...         113
# 1      000846f85c9630becba208506e1585d2b09340e3386088...           7
# 2      0008e5c2621c9af8918f607347e252e854e1a1c0a3988c...           5
# 3      0009d671d687b1e712a501a25b1887bb93d091144d294a...          19
# 4      00101a8c304d1fef6d74f2757b7a1e6107222806af1a9d...           2
# ...                                                  ...         ...
# 20439  fff2120ba40bd52ada46c020e0a3bff30aba3035beedcc...          23
# 20440  fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c63...          14
# 20441  fff81139a7dd8a3a48f462347a5611b8e0b84258237d5d...          30
# 20442  fff82f20ea5aeea53108ebc30fa6e357b15de100fba744...           4
# 20443  fffdbe5b5cc6c01d65c9c9a94ad9cd1dc8546b0b107c11...           1
#
#        total_trip_duration  total_trip_distance
# 0                  89414.0               382.04
# ...

# %%
df_driver_summary
# Out:
#                                                driver_id  trip_count  \
# 0      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...         113
# 1      000846f85c9630becba208506e1585d2b09340e3386088...           7
# 2      0008e5c2621c9af8918f607347e252e854e1a1c0a3988c...           5
# 3      0009d671d687b1e712a501a25b1887bb93d091144d294a...          19
# 4      00101a8c304d1fef6d74f2757b7a1e6107222806af1a9d...           2
# ...                                                  ...         ...
# 20439  fff2120ba40bd52ada46c020e0a3bff30aba3035beedcc...          23
# 20440  fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c63...          14
# 20441  fff81139a7dd8a3a48f462347a5611b8e0b84258237d5d...          30
# 20442  fff82f20ea5aeea53108ebc30fa6e357b15de100fba744...           4
# 20443  fffdbe5b5cc6c01d65c9c9a94ad9cd1dc8546b0b107c11...           1
#
#        total_trip_duration  total_trip_distance
# 0                  89414.0               382.04
# ...

# %%
df_driver_summary["number of days"]=0

# %%
df_driver_summary
# Out:
#                                                driver_id  trip_count  \
# 0      0001da624eada828c3f744b73bacd8e15cf0d3e288bd09...         113
# 1      000846f85c9630becba208506e1585d2b09340e3386088...           7
# 2      0008e5c2621c9af8918f607347e252e854e1a1c0a3988c...           5
# 3      0009d671d687b1e712a501a25b1887bb93d091144d294a...          19
# 4      00101a8c304d1fef6d74f2757b7a1e6107222806af1a9d...           2
# ...                                                  ...         ...
# 20439  fff2120ba40bd52ada46c020e0a3bff30aba3035beedcc...          23
# 20440  fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c63...          14
# 20441  fff81139a7dd8a3a48f462347a5611b8e0b84258237d5d...          30
# 20442  fff82f20ea5aeea53108ebc30fa6e357b15de100fba744...           4
# 20443  fffdbe5b5cc6c01d65c9c9a94ad9cd1dc8546b0b107c11...           1
#
#        total_trip_duration  total_trip_distance  number of days
# 0                  89414.0               382.04               0
# ...

# %%
day1=df1.driver_id.unique()
day2=df2.driver_id.unique()
day3=df3.driver_id.unique()
day4=df4.driver_id.unique()
day5=df5.driver_id.unique()
day6=df6.driver_id.unique()
day7=df7.driver_id.unique()
day8=df8.driver_id.unique()
day9=df9.driver_id.unique()
day10=df10.driver_id.unique()
day11=df11.driver_id.unique()
day12=df12.driver_id.unique()
day13=df13.driver_id.unique()
day14=df14.driver_id.unique()
day15=df15.driver_id.unique()
day16=df16.driver_id.unique()
day17=df17.driver_id.unique()
day18=df18.driver_id.unique()
day19=df19.driver_id.unique()
day20=df20.driver_id.unique()
day21=df21.driver_id.unique()
days=[day1,day2,day3,day4,day5,day6,day7,day8,day9,day10,day11,day12,day13,day14,day15,day16,day17,day18,day19,day20,day21]

# %%
days
# Out:
# [array(['0001da624eada828c3f744b73bacd8e15cf0d3e288bd092d68167dd1bab66e76',
#         '000846f85c9630becba208506e1585d2b09340e33860887403a56fd4eeaa7ea0',
#         '0009d671d687b1e712a501a25b1887bb93d091144d294a03e7368df35faeebfc',
#         ...,
#         'ffe9ccf8ceec33246c2f9c31aee6ade5de621271b25f4936a2a65003ff706da6',
#         'ffefa9fc58deb38517fe5176a458e9cac5c125f15bae31854e0ac451b794d699',
#         'fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c636f2990d831a736a415'],
#        dtype=object),
#  array(['0001da624eada828c3f744b73bacd8e15cf0d3e288bd092d68167dd1bab66e76',
#         '0009d671d687b1e712a501a25b1887bb93d091144d294a03e7368df35faeebfc',
#         '0038263cc90dfa55d621a6425e46020136a318d12b974340f518892a6ef690ff',
#         ...,
#         'ffefa9fc58deb38517fe5176a458e9cac5c125f15bae31854e0ac451b794d699',
#         'fff4cf77e4aa669df808c1ea6644a7297ed41ff8ab4c636f2990d831a736a415',
#         'fff82f20ea5aeea53108ebc30fa6e357b15de100fba74404742f532b4958f5c5'],
# ...

# %%
def find_days(driverid,days):
    count=0
    for j in days:
        if driverid in j:
            count+=1
    
    return count

# %%
for index, row in df_driver_summary.iterrows():
    print (row[0])
# Out:
# 0001da624eada828c3f744b73bacd8e15cf0d3e288bd092d68167dd1bab66e76
# 000846f85c9630becba208506e1585d2b09340e33860887403a56fd4eeaa7ea0
# 0008e5c2621c9af8918f607347e252e854e1a1c0a3988c25bc03fc09b1d885cb
# 0009d671d687b1e712a501a25b1887bb93d091144d294a03e7368df35faeebfc
# 00101a8c304d1fef6d74f2757b7a1e6107222806af1a9df621c43b6e2a3b5499
# 0011ac276e06b1ca66e40714f9bc33eeb5690afdecf776d631687ba5eff263a3
# 001237443e5fae21741fea334f2dc99fb9a316472b9a390ca784b83ac9ad15ef
# 0015186d69bd5c8f47e95ce547d293bad7b246c244def5e6d9c275c7250aed14
# 001859e922f324eb3ce48561314b4bd1d0484dfce5201cb864a4ee2a1f237989
# 00185f50ae7380e7fc7c9ec5b6c7b3eb7edeb5dd7ce4a99c743c8eac8f58023f
# 001a39f0899cfc0232a09c2607ba37b9e949ef88b999118be1d8939a0095944d
# 001a46f34885f1e445f8418c9787ead35aeb67669e77d27806f2171c8712a17b
# 001c0ba08ca82e37b74ac8637b41da6a216a721c04f591d0388df75c9dbdc867
# 001f5b2bb213228cf554d42ac7bcf098b6130fb07125e0eddac9611d7e95dd2a
# ...

# %%
for index, row in df_driver_summary.iterrows():
    day_count=find_days(row[0],days)
    df_driver_summary.at[index,'number of days']=day_count

# %%
df_driver_summary["number of days"].describe()
# Out:
# count    20444.000000
# mean         6.472755
# std          4.816812
# min          1.000000
# 25%          2.000000
# 50%          5.000000
# 75%         10.000000
# max         21.000000
# Name: number of days, dtype: float64

# %%
df_driver_summary.to_csv("clean_summary_21days.csv")
